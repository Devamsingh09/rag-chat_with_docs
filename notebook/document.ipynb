# %%
# !python --version
# Out:
# Python 3.11.7

# %%
from langchain_core.documents import Document
doc=Document(
    page_content="This is tha page content I am using to utilize the RAG.",
    metadata={
        "source": "example.txt",
        "pages": 1,
        "author": "Krish Naik",
        "date_created":"2024-01-01"
    }
)

# %%
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
loader

# %%
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Alright — let’s take a **deep dive into Python’s Object-Oriented Programming (OOP)** — one of the most powerful and widely used aspects of the language.\nHere’s a detailed, 500+ word explanation that balances conceptual clarity with interview-level depth. 👇\n\n---\n\n 🐍 Python and Object-Oriented Programming (OOP)\n\nPython is a **multi-paradigm** language, which means it supports different styles of programming — procedural, functional, and object-oriented. However, **OOP** is one of its most important paradigms because it helps developers structure complex software systems into **modular, reusable, and maintainable** components.\n\n---\n\n🧩 What is Object-Oriented Programming?\n\nAt its core, OOP is based on the idea of representing **real-world entities as objects**. Each object bundles **data (attributes)** and **behavior (methods)** into a single unit. This approach improves organization and makes large programs easier to manage.\n\nIn Python, *everything is an object* — integers, strings, lists, even functions and classes themselves.\n\n---\n 🏗️ Core Concepts of OOP in Python\n1. Classes and Objects\n\nA class is like a blueprint for creating objects. It defines the properties (variables) and methods (functions) that the object will have.\n\n```python\nclass Car:\n    def __init__(self, brand, model):\n        self.brand = brand\n        self.model = model\n\n    def show_details(self):\n        print(f"Car: {self.brand} {self.model}")\n\nmy_car = Car("Tesla", "Model S")\nmy_car.show_details()\n```\n\nHere, `Car` is a class, and `my_car` is an object (or instance) of that class.\nThe `__init__` method is the constructor, which initializes the object’s attributes.\n\n---\n2. Encapsulation\n\nEncapsulation means **hiding internal data from outside interference and misuse. In Python, we use underscores to indicate visibility:\n\n `_variable`: protected (by convention)\n `__variable`: private (name-mangled internally)\n\n```python\nclass BankAccount:\n    def __init__(self, balance):\n        self.__balance = balance  # private variable\n\n    def deposit(self, amount):\n        self.__balance += amount\n\n    def get_balance(self):\n        return self.__balance\n```\n\nEncapsulation improve security and data integrity, ensuring that data is accessed only through controlled interfaces.\n\n---\n\n3. Inheritance\n\nInheritance allows one class (child) to acquire attributes and methods from another (parent), promoting **code reuse**.\n\n```python\nclass Vehicle:\n    def start(self):\n        print("Vehicle starting...")\n\nclass Bike(Vehicle):\n    def ride(self):\n        print("Bike riding...")\n\nb = Bike()\nb.start()\nb.ride()\n```\n\nHere, `Bike` inherits from `Vehicle`, so it gains access to `start()` without redefining it.\n\nPython also supports:\n\n* Single inheritance\n* Multiple inheritance\n* Multilevel inheritance\n\nHowever, multiple inheritance should be used carefully to avoid ambiguity (the “diamond problem”).\n\n---\n\n4. Polymorphism\n\nPolymorphism means same function name, different behavior based on the object.\n\n```python\nclass Dog:\n    def speak(self):\n        return "Woof!"\n\nclass Cat:\n    def speak(self):\n        return "Meow!"\n\nfor animal in [Dog(), Cat()]:\n    print(animal.speak())\n```\n\nThis allows flexibility in code — you can call `speak()` without caring which specific object is being used.\n\n---\n\n5. Abstraction\n\nAbstraction hides **complex implementation details** and exposes only the necessary parts.\nIn Python, abstraction can be implemented using the `abc` (Abstract Base Class) module.\n\n```python\nfrom abc import ABC, abstractmethod\n\nclass Shape(ABC):\n    @abstractmethod\n    def area(self):\n        pass\n\nclass Circle(Shape):\n    def __init__(self, radius):\n        self.radius = radius\n    def area(self):\n        return 3.14 * self.radius ** 2\n```\n\nHere, `Shape` defines an in ...

# %%
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=True
)

documents=dir_loader.load()
print(documents)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 616.36it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learninig.txt'}, page_content='### 🤖 Machine Learning in Detail\n\nMachine Learning (ML) is a core branch of Artificial Intelligence (AI) that focuses on building systems capable of learning from data and improving performance without being explicitly programmed. Instead of following fixed instructions, ML algorithms identify patterns and relationships within data to make predictions, decisions, or generate insights.\n\n---\n\n### 🧠 What is Machine Learning?\n\nAt its heart, ML is about using data-driven models to approximate complex functions. For instance, a traditional program might use if-else rules to detect spam emails, but an ML system would learn directly from examples of spam and non-spam messages.\n\nIn simple terms:\n\n> Machine Learning = Data + Algorithms + Experience → Improved Performance\n\nThe algorithm adapts over time as it sees more data, improving its predictions or classifications.\n\n---\n\n### 🧩 Types of Machine Learning\n\n#### 1. Supervised Learning\n\nThis is the most common type, where the model is trained on labeled data (input with known outputs).\n\nExample: Predicting house prices based on area, location, and number of rooms.\n\n* Regression → Predict continuous values (e.g., prices, temperatures)\n* Classification → Predict discrete categories (e.g., spam/not spam)\n\nPopular algorithms:\n\n* Linear Regression\n* Logistic Regression\n* Decision Trees\n* Random Forests\n* Support Vector Machines (SVM)\n* Neural Networks\n\n#### 2. Unsupervised Learning\n\nIn this approach, the data is unlabeled — the algorithm must find structure or patterns on its own.\n\nExamples:\n\n* Clustering customers by purchase behavior.\n* Reducing dimensions of a dataset (e.g., PCA).\n\nPopular algorithms:\n\n* K-Means Clustering\n* Hierarchical Clustering\n* Principal Component Analysis (PCA)\n* Autoencoders\n\n#### 3. Semi-Supervised Learning\n\nUsed when only a small portion of data is labeled and the rest is unlabeled. The model learns from both, improving efficiency.\n\nExample: Detecting fraud where only a few examples are labeled as fraudulent.\n\n#### 4. Reinforcement Learning (RL)\n\nHere, an agent learns to make decisions through trial and error by receiving feedback (rewards or penalties).\n\nExample: Teaching a robot to walk or an AI to play chess.\n\nKey terms:\n\n* Agent: Learner or decision maker.\n* Environment: The world the agent interacts with.\n* Reward: Feedback signal for success.\n\nPopular RL algorithms:\n\n* Q-Learning\n* Deep Q-Networks (DQN)\n* Policy Gradients\n\n---\n\n### ⚙️ The Machine Learning Workflow\n\n1. Data Collection – Gather structured or unstructured data from sensors, APIs, or databases.\n2. Data Cleaning & Preprocessing – Handle missing values, normalize features, and remove noise.\n3. Feature Engineering – Select or create meaningful attributes that help the model learn.\n4. Model Selection – Choose the best algorithm (e.g., Linear Regression, XGBoost, Neural Network).\n5. Training – Feed data into the model so it can learn patterns.\n6. Evaluation – Measure performance using metrics like accuracy, precision, recall, F1-score, RMSE, etc.\n7. Deployment – Integrate the trained model into a production environment for real-world use.\n\n---\n\n### 📊 Key Evaluation Metrics\n\n* Accuracy – Fraction of correct predictions.\n* Precision – How many predicted positives are actually positive.\n* Recall – How many actual positives were correctly identified.\n* F1 Score – Harmonic mean of precision and recall.\n* RMSE / MAE – Common metrics for regression performance.\n\n---\n\n### 🧬 Important ML Concepts\n\n* Overfitting: The model performs well on training data but poorly on unseen data.\n* Underfitting: The model is too simple and fails to capture patterns.\n* Bias-Variance Tradeoff: Balancing model complexity and generalization.\n* Cross-Validation: Splitting data into multiple parts to ensure robustness.\n* Regularization ...

# %%
import numpy as np
from sentence_transformers import SentenceTransformers
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity
